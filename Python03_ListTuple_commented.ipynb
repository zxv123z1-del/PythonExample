# %%
# 예제 설명: 리스트는 여러 값을 순서대로 저장하는 자료형이라는 것을 보여줍니다.
thislist = ["apple", "banana", "cherry"] 
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# 예제 설명: 리스트는 같은 값을 여러 번 저장할 수 있다는 예제입니다.
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
# 예제 설명: len()으로 리스트 안의 항목 개수를 확인하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
print(len(thislist))
# Out:
# 3

# %%
# 예제 설명: 리스트에는 문자열, 숫자, 불리언처럼 같은 종류의 값들을 담을 수 있다는 예제입니다.
list1 = ["apple", "banana", "cherry"] 
list2 = [1, 5, 7, 9, 3] 
list3 = [True, False, False]

# %%
# 예제 설명: 리스트에는 서로 다른 자료형을 섞어서 넣을 수 있다는 예제입니다.
list1 = ["abc", 34, True, 40, "male"]

# %%
# 예제 설명: type()으로 리스트 자료형이 list인지 확인하는 예제입니다.
mylist = ["apple", "banana", "cherry"] 
print(type(mylist))
# Out:
# <class 'list'>

# %%
# 예제 설명: list() 생성자를 사용해 튜플을 리스트로 바꾸는 예제입니다.
thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# 예제 설명: 인덱스 번호로 리스트의 특정 항목을 꺼내는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
print(thislist[1])
# Out:
# banana

# %%
# 예제 설명: 음수 인덱스로 리스트의 뒤쪽 항목을 꺼내는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
print(thislist[-1])
# Out:
# cherry

# %%
# 예제 설명: 슬라이싱으로 리스트의 일부 구간을 가져오는 예제입니다.
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
# 예제 설명: 시작 인덱스를 생략하면 처음부터 지정 위치 전까지 가져오는 예제입니다.
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
# 예제 설명: 끝 인덱스를 생략하면 지정 위치부터 끝까지 가져오는 예제입니다.
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:])
# Out:
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
# 예제 설명: 인덱스를 이용해 리스트의 특정 값을 변경하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist[1] = "blackcurrant" 
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
# 예제 설명: 슬라이싱 구간에 새 리스트를 넣어 여러 값을 한 번에 바꾸는 예제입니다.
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"] 
thislist[1:3] = ["blackcurrant", "watermelon"] 
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
# 예제 설명: 하나의 항목 자리에 여러 항목을 넣어 리스트 길이가 늘어나는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist[1:2] = ["blackcurrant", "watermelon"] 
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
# 예제 설명: 여러 항목 구간을 하나의 항목으로 바꿔 리스트 길이가 줄어드는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist[1:3] = ["watermelon"] 
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
# 예제 설명: append()로 리스트 끝에 항목을 추가하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist.append("orange") 
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
# 예제 설명: insert()로 원하는 위치에 항목을 끼워 넣는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist.insert(1, "orange") 
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
# 예제 설명: extend()로 다른 리스트의 항목들을 뒤에 붙이는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
tropical = ["mango", "pineapple", "papaya"] 
thislist.extend(tropical) 
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
# 예제 설명: extend()는 튜플 같은 다른 반복 가능한 자료형도 리스트에 붙일 수 있다는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thistuple = ("kiwi", "orange") 
thislist.extend(thistuple) 
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
# 예제 설명: remove()로 특정 값을 가진 항목을 삭제하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist.remove("banana") 
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
# 예제 설명: 같은 값이 여러 개 있으면 remove()는 첫 번째 항목만 삭제한다는 예제입니다.
thislist = ["apple", "banana", "cherry", "banana", "kiwi"] 
thislist.remove("banana") 
print(thislist)
# Out:
# ['apple', 'cherry', 'banana', 'kiwi']

# %%
# 예제 설명: pop(인덱스)로 지정 위치의 항목을 삭제하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist.pop(1) 
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
# 예제 설명: pop()에 인덱스를 쓰지 않으면 마지막 항목을 삭제한다는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
thislist.pop() 
print(thislist)
# Out:
# ['apple', 'banana']

# %%
# 예제 설명: del로 특정 인덱스의 항목을 삭제하는 예제입니다.
thislist = ["apple", "banana", "cherry"]
del thislist[0] 
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
# 예제 설명: del로 리스트 변수 자체를 삭제하는 예제입니다.
thislist = ["apple", "banana", "cherry"]
del thislist

# %%
# 예제 설명: clear()로 리스트는 남기고 내부 항목만 모두 비우는 예제입니다.
thislist = ["apple", "banana", "cherry"]
thislist.clear() 
print(thislist)
# Out:
# []

# %%
# 예제 설명: for문으로 리스트 항목을 하나씩 꺼내는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
for x in thislist: 
    print(x)
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: range(len())를 사용해 인덱스로 리스트를 반복하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
for i in range(len(thislist)): 
    print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: while문으로 조건을 만족하는 동안 리스트를 반복 출력하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
i = 0 
while i < len(thislist): 
    print(thislist[i]) 
    i = i + 1
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: 리스트 컴프리헨션 형태로 각 항목을 출력하는 짧은 표현 예제입니다.
thislist = ["apple", "banana", "cherry"] 
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
# 예제 설명: for문과 if문으로 조건에 맞는 항목만 새 리스트에 담는 예제입니다.
fruits = ["apple", "banana", "cherry", "kiwi", "mango"] 
newlist = [] 
for x in fruits: 
    if "a" in x: 
        newlist.append(x)

# %%
# 예제 설명: 리스트 컴프리헨션으로 조건 필터링을 짧게 작성하는 예제입니다.
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x] 
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
# 예제 설명: 리스트 컴프리헨션으로 특정 값을 제외하고 새 리스트를 만드는 예제입니다.
newlist = [x for x in fruits if x != "apple"]

# %%
# 예제 설명: 리스트 컴프리헨션으로 기존 리스트를 그대로 복사하는 예제입니다.
newlist = [x for x in fruits]

# %%
# 예제 설명: range()와 리스트 컴프리헨션으로 숫자 리스트를 만드는 예제입니다.
newlist = [x for x in range(10)]

# %%
# 예제 설명: 조건문을 넣어 원하는 숫자만 리스트로 만드는 예제입니다.
newlist = [x for x in range(10) if x < 5]

# %%
# 예제 설명: 각 문자열에 upper()를 적용해 대문자 리스트를 만드는 예제입니다.
newlist = [x.upper() for x in fruits]

# %%
# 예제 설명: 모든 항목을 같은 값으로 바꾼 새 리스트를 만드는 예제입니다.
newlist = ['hello' for x in fruits]

# %%
# 예제 설명: 조건 표현식을 사용해 특정 항목만 다른 값으로 바꾸는 예제입니다.
newlist = [x if x != "banana" else "orange" for x in fruits]

# %%
# 예제 설명: sort()로 문자열 리스트를 알파벳 순서로 정렬하는 예제입니다.
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"] 
thislist.sort() 
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
# 예제 설명: sort()로 숫자 리스트를 오름차순 정렬하는 예제입니다.
thislist = [100, 50, 65, 82, 23]
thislist.sort() 
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
# 예제 설명: copy()로 리스트를 복사하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
mylist = thislist.copy() 
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# 예제 설명: list() 생성자로 리스트를 복사하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
mylist = list(thislist) 
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# 예제 설명: 슬라이싱 [:]으로 리스트 전체를 복사하는 예제입니다.
thislist = ["apple", "banana", "cherry"] 
mylist = thislist[:] 
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
# 예제 설명: + 연산자로 두 리스트를 하나로 합치는 예제입니다.
list1 = ["a", "b", "c"] 
list2 = [1, 2, 3] 
list3 = list1 + list2 
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 예제 설명: for문과 append()로 한 리스트의 항목을 다른 리스트에 하나씩 추가하는 예제입니다.
list1 = ["a", "b", "c"] 
list2 = [1, 2, 3] 
for x in list2: 
    list1.append(x) 
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 예제 설명: extend()로 두 리스트를 간단히 합치는 예제입니다.
list1 = ["a", "b", "c"] 
list2 = [1, 2, 3] 
list1.extend(list2) 
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
# 예제 설명: 튜플은 여러 값을 순서대로 저장하지만 변경이 어렵다는 자료형의 기본 예제입니다.
thistuple = ("apple", "banana", "cherry") 
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
# 예제 설명: 튜플도 리스트처럼 중복 값을 저장할 수 있다는 예제입니다.
thistuple = ("apple", "banana", "cherry", "apple", "cherry") 
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
# 예제 설명: len()으로 튜플의 항목 개수를 확인하는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
print(len(thistuple))
# Out:
# 3

# %%
# 예제 설명: 항목이 하나인 튜플은 반드시 쉼표가 필요하다는 예제입니다.
thistuple = ("apple",) 
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
# 예제 설명: 튜플에도 문자열, 숫자, 불리언 등을 담을 수 있다는 예제입니다.
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3) 
tuple3 = (True, False, False)

# %%
# 예제 설명: 튜플에도 서로 다른 자료형을 섞어 넣을 수 있다는 예제입니다.
tuple1 = ("abc", 34, True, 40, "male")

# %%
# 예제 설명: type()으로 튜플 자료형이 tuple인지 확인하는 예제입니다.
mytuple = ("apple", "banana", "cherry") 
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
# 예제 설명: tuple() 생성자로 튜플을 만드는 예제입니다.
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
# 예제 설명: 인덱스로 튜플의 특정 항목을 가져오는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
print(thistuple[1])
# Out:
# banana

# %%
# 예제 설명: 음수 인덱스로 튜플의 마지막 항목을 가져오는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
print(thistuple[-1])
# Out:
# cherry

# %%
# 예제 설명: 슬라이싱으로 튜플의 일부 구간을 가져오는 예제입니다.
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %%
# 예제 설명: 시작 인덱스를 생략해 처음부터 원하는 구간까지 가져오는 예제입니다.
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
# 예제 설명: 끝 인덱스를 생략해 특정 위치부터 끝까지 가져오는 예제입니다.
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
# 예제 설명: 튜플은 직접 수정할 수 없으므로 리스트로 바꾼 뒤 수정하고 다시 튜플로 바꾸는 예제입니다.
x = ("apple", "banana", "cherry") 
y = list(x) 
y[1] = "kiwi" 
x = tuple(y) 
print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
# 예제 설명: 튜플에 값을 추가하려면 리스트로 바꿨다가 다시 튜플로 만드는 방법을 보여줍니다.
thistuple = ("apple", "banana", "cherry") 
y = list(thistuple) 
y.append("orange") 
thistuple = tuple(y)

# %%
# 예제 설명: 튜플끼리 더해서 새 항목을 추가한 것처럼 만들 수 있다는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
y = ("orange",) 
thistuple += y 
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
# 예제 설명: 여러 값을 튜플 하나에 묶어 저장하는 튜플 패킹 예제입니다.
fruits = ("apple", "banana", "cherry")

# %%
# 예제 설명: 튜플의 값을 여러 변수로 나누어 받는 언패킹 예제입니다.
fruits = ("apple", "banana", "cherry") 
(green, yellow, red) = fruits 
print(green) 
print(yellow) 
print(red)
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: for문으로 튜플 항목을 하나씩 출력하는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
for x in thistuple: 
    print(x)
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: range(len())로 인덱스를 이용해 튜플을 반복하는 예제입니다.
thistuple = ("apple", "banana", "cherry") 
for i in range(len(thistuple)): 
    print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
# 예제 설명: + 연산자로 두 튜플을 하나로 합치는 예제입니다.
tuple1 = ("a", "b", "c") 
tuple2 = (1, 2, 3) 
tuple3 = tuple1 + tuple2 
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
# 예제 설명: * 연산자로 튜플 내용을 반복해 새 튜플을 만드는 예제입니다.
fruits = ("apple", "banana", "cherry") 
mytuple = fruits * 2 
print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
# 예제 설명: 세트는 여러 값을 순서 없이 저장하는 자료형이라는 것을 보여줍니다.
thisset = {"apple", "banana", "cherry"} 
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
# 예제 설명: 세트는 중복 값을 자동으로 제거한다는 예제입니다.
thisset = {"apple", "banana", "cherry", "apple"} 
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
# 예제 설명: 세트에서는 True와 1이 같은 값처럼 취급될 수 있다는 예제입니다.
thisset = {"apple", "banana", "cherry", True, 1, 2} 
print(thisset)
# Out:
# {'cherry', True, 2, 'banana', 'apple'}

# %%
# 예제 설명: 세트에서는 False와 0이 같은 값처럼 취급될 수 있다는 예제입니다.
thisset = {"apple", "banana", "cherry", False, True, 0} 
print(thisset)
# Out:
# {'cherry', False, True, 'banana', 'apple'}
